# %% [markdown]
# # 🧠 DL Tuning Challenge — Starter Notebook
#
# **Mata Kuliah:** DSB07 – Machine Learning
# **Topik:** Hyperparameter Tuning pada Deep Neural Network
# **Dataset:** Fashion-MNIST (10 kelas pakaian, 28×28 grayscale)
#
# ## Instruksi
#
# 1. **Jalankan SEMUA cell** dari atas ke bawah untuk mendapatkan baseline.
# 2. Ubah hyperparameter HANYA di section **🎛️ HYPERPARAMETER PANEL**.
# 3. **JANGAN** mengubah cell ber-label **🔒 LOCKED**.
# 4. Catat setiap eksperimen di `EXPERIMENTS.md`.
#
# > 💡 **Tips:** Aktifkan GPU runtime: `Runtime → Change runtime type → T4 GPU`

# %% [markdown]
# ## 🔒 LOCKED — Setup & Data Loading
#
# **Jangan ubah cell ini.** Cell ini me-load dataset dengan cara yang sama untuk semua kelompok agar penilaian adil.

# %%
# 🔒 LOCKED — JANGAN UBAH
import numpy as np
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt

# Reproducibility — jangan ubah seed ini
SEED = 42
np.random.seed(SEED)
tf.random.set_seed(SEED)

# Load Fashion-MNIST
(x_train, y_train), (x_test, y_test) = keras.datasets.fashion_mnist.load_data()

# Normalisasi ke [0, 1]
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0

# Flatten 28x28 → 784 (untuk MLP sederhana)
x_train_flat = x_train.reshape(-1, 784)
x_test_flat = x_test.reshape(-1, 784)

CLASS_NAMES = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

print(f'Train: {x_train.shape},  Test: {x_test.shape}')
print(f'Jumlah kelas: {len(CLASS_NAMES)}')

# Visualisasi sample
fig, axes = plt.subplots(2, 5, figsize=(10, 4))
for i, ax in enumerate(axes.flat):
    ax.imshow(x_train[i], cmap='gray')
    ax.set_title(CLASS_NAMES[y_train[i]], fontsize=9)
    ax.axis('off')
plt.tight_layout()
plt.show()
# Out:
# Train: (60000, 28, 28),  Test: (10000, 28, 28)
# Jumlah kelas: 10

# %% [markdown]
# ## 🎛️ HYPERPARAMETER PANEL
#
# **Ini area bermain kalian.** Ubah nilai-nilai di bawah dan amati pengaruhnya.
#
# Setiap variabel di bawah memetakan langsung ke konsep yang dipelajari di kelas:
#
# | Variabel | Konsep di Slide |
# |---|---|
# | `HIDDEN_LAYERS` | Jumlah Lapisan |
# | `NEURONS_PER_LAYER` | Jumlah Neuron |
# | `ACTIVATION` | Fungsi Aktivasi |
# | `OPTIMIZER` | Optimizer (Adam, SGD, dst) |
# | `LEARNING_RATE` | Learning Rate (λ) |
# | `BATCH_SIZE` | Batch Size |
# | `EPOCHS` | Epoch |
# | `DROPOUT_RATE` | (Bonus) regularisasi |

# %%
# 🎛️ UBAH NILAI-NILAI DI BAWAH INI

# --- Arsitektur Model ---
HIDDEN_LAYERS     = 1            # jumlah hidden layer (coba: 1, 2, 3, 4, 5)
NEURONS_PER_LAYER = 128           # jumlah neuron per hidden layer (coba: 32, 64, 128, 256, 512)
ACTIVATION        = 'tanh'       # 'relu', 'tanh', 'sigmoid', 'elu', 'selu'
DROPOUT_RATE      = 0.3          # 0.0 = tidak ada dropout. Coba 0.2 / 0.3 / 0.5 untuk regularisasi

# --- Optimizer & Pelatihan ---
OPTIMIZER     = 'adam'            # 'sgd', 'adam', 'adamax', 'rmsprop'
LEARNING_RATE = 0.001             # coba: 0.0001, 0.001, 0.01, 0.1, 1.0
BATCH_SIZE    = 32               # coba: 16, 32, 64, 128, 256, 512
EPOCHS        = 50               # coba: 5, 10, 20, 50

# --- Catatan untuk eksperimen ini (akan dicetak di summary) ---
EXPERIMENT_NOTE = 'Baseline run — belum di-tuning'

# %% [markdown]
# ## 🔒 LOCKED — Model Builder
#
# Cell ini membangun model berdasarkan hyperparameter di atas. Tidak perlu diubah.

# %%
# 🔒 LOCKED — JANGAN UBAH

def build_model():
    """Bangun MLP berdasarkan hyperparameter panel."""
    model = keras.Sequential(name='TuningChallengeModel')
    model.add(keras.layers.Input(shape=(784,)))

    for i in range(HIDDEN_LAYERS):
        model.add(keras.layers.Dense(
            NEURONS_PER_LAYER,
            activation=ACTIVATION,
            name=f'hidden_{i+1}'
        ))
        if DROPOUT_RATE > 0:
            model.add(keras.layers.Dropout(DROPOUT_RATE))

    # Output layer — 10 kelas, JANGAN diubah
    model.add(keras.layers.Dense(10, activation='softmax', name='output'))
    return model


def get_optimizer():
    """Map string optimizer ke Keras optimizer dengan learning rate."""
    opts = {
        'sgd':     keras.optimizers.SGD(learning_rate=LEARNING_RATE),
        'adam':    keras.optimizers.Adam(learning_rate=LEARNING_RATE),
        'adamax':  keras.optimizers.Adamax(learning_rate=LEARNING_RATE),
        'rmsprop': keras.optimizers.RMSprop(learning_rate=LEARNING_RATE),
    }
    if OPTIMIZER.lower() not in opts:
        raise ValueError(f'Optimizer "{OPTIMIZER}" tidak dikenal. Pilih: {list(opts.keys())}')
    return opts[OPTIMIZER.lower()]


# Build & compile
model = build_model()
model.compile(
    optimizer=get_optimizer(),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

model.summary()

# Hitung total parameter (bobot + bias) — visualisasikan konsep 'parameter'
total_params = model.count_params()
print(f'\n📊 Total parameter (bobot + bias) yang akan di-learn: {total_params:,}')
# Out:
# Model: "TuningChallengeModel"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ hidden_1 (Dense)                │ (None, 128)            │       100,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output (Dense)                  │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 101,770 (397.54 KB)
#  Trainable params: 101,770 (397.54 KB)
#  Non-trainable params: 0 (0.00 B)
# 📊 Total parameter (bobot + bias) yang akan di-learn: 101,770

# %% [markdown]
# ## 🔒 LOCKED — Training
#
# Cell ini menjalankan **feed forward + back propagation** sesuai jumlah epoch yang kalian tentukan.

# %%
# 🔒 LOCKED — JANGAN UBAH

import time

start = time.time()
history = model.fit(
    x_train_flat, y_train,
    batch_size=BATCH_SIZE,
    epochs=EPOCHS,
    validation_split=0.1,   # 10% dari training jadi validation
    verbose=1
)
duration = time.time() - start
print(f'\n⏱️  Total waktu training: {duration:.1f} detik')
# Out:
# Epoch 1/50
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - accuracy: 0.8015 - loss: 0.5518 - val_accuracy: 0.8390 - val_loss: 0.4369
# Epoch 2/50
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.8418 - loss: 0.4393 - val_accuracy: 0.8470 - val_loss: 0.4060
# Epoch 3/50
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.8523 - loss: 0.4113 - val_accuracy: 0.8550 - val_loss: 0.3823
# Epoch 4/50
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.8590 - loss: 0.3916 - val_accuracy: 0.8613 - val_loss: 0.3735
# Epoch 5/50
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.8646 - loss: 0.3749 - val_accuracy: 0.8653 - val_loss: 0.3615
# Epoch 6/50
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.8673 - loss: 0.3645 - val_accuracy: 0.8680 - val_loss: 0.3529
# Epoch 7/50
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.8697 - loss: 0.3559 - val_accuracy: 0.8705 - val_loss: 0.3477
# Epoch 8/50
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.8728 - loss: 0.3481 - val_accuracy: 0.8727 - val_loss: 0.3481
# Epoch 9/50
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.8763 - loss: 0.3416 - val_accuracy: 0.8753 - val_loss: 0.3399
# Epoch 10/50
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.8773 - loss: 0.3346 - val_accuracy: 0.8728 - val_loss: 0.3361
# Epoch 11/50
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.8782 - loss: 0.3294 - val_accuracy: 0.8763 - val_loss: 0.3291
# Epoch 12/50
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.8805 - loss: 0.3257 - val_accuracy: 0.8768 - val_loss: 0.3308
# Epoch 13/50
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.8826 - loss: 0.3170 - val_accuracy: 0.8762 - val_loss: 0.3298
# Epoch 14/50
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.8842 - loss: 0.3132 - val_accuracy: 0.8752 - val_loss: 0.3346
# Epoch 15/50
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.8846 - loss: 0.3120 - val_accuracy: 0.8778 - val_loss: 0.3366
# Epoch 16/50
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.8867 - loss: 0.3077 - val_accuracy: 0.8747 - val_loss: 0.3350
# Epoch 17/50
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.8890 - loss: 0.3015 - val_accuracy: 0.8793 - val_loss: 0.3288
# Epoch 18/50
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.8890 - loss: 0.3027 - val_accuracy: 0.8780 - val_loss: 0.3320
# Epoch 19/50
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.8905 - loss: 0.2969 - val_accuracy: 0.8800 - val_loss: 0.3297
# Epoch 20/50
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.8907 - loss: 0.2958 - val_accuracy: 0.8788 - val_loss: 0.3265
# Epoch 21/50
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.8927 - loss: 0.2926 - val_accuracy: 0.8788 - val_loss: 0.3290
# Epoch 22/50
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.8951 - loss: 0.2890 - val_accuracy: 0.8807 - val_loss: 0.3204
# Epoch 23/50
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.8941 - loss: 0.2858 - val_accuracy: 0.8813 - val_loss: 0.3253
# Epoch 24/50
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.8955 - loss: 0.2830 - val_accuracy: 0.8808 - val_loss: 0.3267
# Epoch 25/50
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.8957 - loss: 0.2836 - val_accuracy: 0.8797 - val_loss: 0.3296
# Epoch 26/50
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.8972 - loss: 0.2779 - val_accuracy: 0.8822 - val_loss: 0.3250
# Epoch 27/50
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.8973 - loss: 0.2780 - val_accuracy: 0.8820 - val_loss: 0.3237
# Epoch 28/50
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.8986 - loss: 0.2737 - val_accuracy: 0.8810 - val_loss: 0.3299
# Epoch 29/50
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9000 - loss: 0.2720 - val_accuracy: 0.8817 - val_loss: 0.3260
# Epoch 30/50
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.8981 - loss: 0.2728 - val_accuracy: 0.8828 - val_loss: 0.3262
# Epoch 31/50
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.8999 - loss: 0.2693 - val_accuracy: 0.8827 - val_loss: 0.3298
# Epoch 32/50
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9011 - loss: 0.2676 - val_accuracy: 0.8830 - val_loss: 0.3352
# Epoch 33/50
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9014 - loss: 0.2670 - val_accuracy: 0.8843 - val_loss: 0.3247
# Epoch 34/50
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9037 - loss: 0.2622 - val_accuracy: 0.8837 - val_loss: 0.3276
# Epoch 35/50
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9021 - loss: 0.2611 - val_accuracy: 0.8802 - val_loss: 0.3325
# Epoch 36/50
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9041 - loss: 0.2592 - val_accuracy: 0.8818 - val_loss: 0.3275
# Epoch 37/50
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9047 - loss: 0.2575 - val_accuracy: 0.8853 - val_loss: 0.3263
# Epoch 38/50
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9047 - loss: 0.2574 - val_accuracy: 0.8822 - val_loss: 0.3301
# Epoch 39/50
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9062 - loss: 0.2567 - val_accuracy: 0.8853 - val_loss: 0.3281
# Epoch 40/50
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9047 - loss: 0.2548 - val_accuracy: 0.8832 - val_loss: 0.3317
# Epoch 41/50
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9045 - loss: 0.2574 - val_accuracy: 0.8870 - val_loss: 0.3228
# Epoch 42/50
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9069 - loss: 0.2535 - val_accuracy: 0.8855 - val_loss: 0.3238
# Epoch 43/50
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9084 - loss: 0.2492 - val_accuracy: 0.8872 - val_loss: 0.3289
# Epoch 44/50
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9067 - loss: 0.2492 - val_accuracy: 0.8847 - val_loss: 0.3301
# Epoch 45/50
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9083 - loss: 0.2474 - val_accuracy: 0.8857 - val_loss: 0.3264
# Epoch 46/50
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9075 - loss: 0.2474 - val_accuracy: 0.8843 - val_loss: 0.3356
# Epoch 47/50
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9110 - loss: 0.2426 - val_accuracy: 0.8842 - val_loss: 0.3327
# Epoch 48/50
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9091 - loss: 0.2454 - val_accuracy: 0.8862 - val_loss: 0.3219
# Epoch 49/50
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9093 - loss: 0.2444 - val_accuracy: 0.8870 - val_loss: 0.3293
# Epoch 50/50
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9105 - loss: 0.2392 - val_accuracy: 0.8910 - val_loss: 0.3205
#
# ⏱️  Total waktu training: 495.9 detik

# %% [markdown]
# ## 🔒 LOCKED — Evaluasi & Visualisasi

# %%
# 🔒 LOCKED — JANGAN UBAH

# Evaluasi pada test set
test_loss, test_acc = model.evaluate(x_test_flat, y_test, verbose=0)

print('='*60)
print(f'📝 Catatan: {EXPERIMENT_NOTE}')
print('='*60)
print(f'Hyperparameter:')
print(f'  Hidden layers     : {HIDDEN_LAYERS}')
print(f'  Neurons per layer : {NEURONS_PER_LAYER}')
print(f'  Activation        : {ACTIVATION}')
print(f'  Dropout rate      : {DROPOUT_RATE}')
print(f'  Optimizer         : {OPTIMIZER}')
print(f'  Learning rate     : {LEARNING_RATE}')
print(f'  Batch size        : {BATCH_SIZE}')
print(f'  Epochs            : {EPOCHS}')
print('-'*60)
print(f'🎯 TEST ACCURACY  : {test_acc*100:.2f}%')
print(f'   Test loss      : {test_loss:.4f}')
print(f'   Train accuracy : {history.history["accuracy"][-1]*100:.2f}%')
print(f'   Val accuracy   : {history.history["val_accuracy"][-1]*100:.2f}%')
print('='*60)

# Plot training curves — visualisasi konkret dari proses backpropagation
fig, axes = plt.subplots(1, 2, figsize=(12, 4))

axes[0].plot(history.history['loss'], label='Train', linewidth=2)
axes[0].plot(history.history['val_loss'], label='Validation', linewidth=2)
axes[0].set_xlabel('Epoch')
axes[0].set_ylabel('Loss (fungsi kerugian)')
axes[0].set_title('Loss — semakin kecil semakin baik')
axes[0].legend()
axes[0].grid(alpha=0.3)

axes[1].plot(history.history['accuracy'], label='Train', linewidth=2)
axes[1].plot(history.history['val_accuracy'], label='Validation', linewidth=2)
axes[1].set_xlabel('Epoch')
axes[1].set_ylabel('Accuracy')
axes[1].set_title('Accuracy — semakin besar semakin baik')
axes[1].legend()
axes[1].grid(alpha=0.3)

plt.tight_layout()
plt.show()

# Diagnostik kecil
gap = history.history['accuracy'][-1] - history.history['val_accuracy'][-1]
if gap > 0.05:
    print(f'⚠️  Gap train vs val = {gap*100:.1f}% — kemungkinan OVERFITTING.')
    print('    Coba: kurangi neuron, tambah dropout, atau kurangi epoch.')
elif history.history['accuracy'][-1] < 0.7:
    print('⚠️  Akurasi train rendah — kemungkinan UNDERFITTING.')
    print('    Coba: tambah neuron/layer, naikkan learning rate, atau tambah epoch.')
else:
    print('✅ Train-val gap sehat. Lanjut eksperimen!')
# Out:
# ============================================================
# 📝 Catatan: Baseline run — belum di-tuning
# ============================================================
# Hyperparameter:
#   Hidden layers     : 1
#   Neurons per layer : 128
#   Activation        : tanh
#   Dropout rate      : 0.3
#   Optimizer         : adam
#   Learning rate     : 0.001
#   Batch size        : 32
#   Epochs            : 50
# ------------------------------------------------------------
# 🎯 TEST ACCURACY  : 88.00%
#    Test loss      : 0.3459
#    Train accuracy : 91.05%
#    Val accuracy   : 89.10%
# ============================================================
# ✅ Train-val gap sehat. Lanjut eksperimen!

# %% [markdown]
# ## 🔍 (Opsional) Inspect Confusion Matrix
#
# Kelas mana yang paling sering tertukar? Insight ini bisa membantu argumentasi di refleksi kalian.

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

y_pred = model.predict(x_test_flat, verbose=0).argmax(axis=1)
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=CLASS_NAMES, yticklabels=CLASS_NAMES)
plt.xlabel('Prediksi')
plt.ylabel('Sebenarnya')
plt.title('Confusion Matrix')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
#
# ## ✅ Checklist Setelah Eksperimen Ini
#
# - [✅] Catat hasilnya di `EXPERIMENTS.md`
# - [✅] Diskusikan dengan tim: *mengapa* hasilnya seperti ini?
# - [✅] Tentukan apa yang akan diubah pada eksperimen berikutnya — dan **kenapa**
# - [ ] Setelah ≥5 eksperimen, pilih konfigurasi terbaik → simpan sebagai `solution.ipynb`
# - [ ] Tulis refleksi di `REFLECTION.md`
